# %%
# multiple line plot

last10years=combined[combined['month']>'01/01/2009'].sort_values('month')
last10years.head()


flat = pd.DataFrame(last10years.groupby(['month','town'])['resale_price'].median())
#flat.to_csv('grouped median prices.csv')


#flat[flat['town']=='MARINE PARADE'].head()


# plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
# plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
# plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
# plt.legend()

# %%
subset = combined[(combined['town']=='MARINE PARADE') & (combined['flat_type'].str.contains('5 ROOM'))]

plt.figure(figsize=(20,10))
# use the plot function
plt.plot(subset['month'],subset['resale_price'],)
plt.show()

# %%
mp_sub = combined[(combined['town']=='MARINE PARADE')& (combined['floor_area_sqm']>120)]
mp_sub.describe()

# %%
plt.figure(figsize=(20,10))
# use the plot function
sns.lineplot(mp_sub['month'],mp_sub['resale_price'],)
plt.show()

# %%
import seaborn as sns
sns.set(style="ticks")

df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")
